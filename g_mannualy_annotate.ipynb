# %%
import pandas as pd
test_file_names = pd.read_csv('D:\\Personal\\Msc\\CMM706 Text Analytics\\Coursework\\\datasets\\test_file_names.csv')
list_of_test_url = []

# Listing test data file names
for index, row in test_file_names.iterrows():
#     print(row[0].split('.'))
    url = 'https://t.co/' + row[0].split('.')[0]
    list_of_test_url.append([row[0] , row[0].split('.')[0], url ])
    
    
list_of_test_url_df = pd.DataFrame(list_of_test_url)
#list_of_test_url_df
list_of_test_url_df.to_csv('D:\\Personal\\Msc\\CMM706 Text Analytics\\Coursework\\\datasets\\test_data_urls.csv', index=None)

# %%
test_file_names = pd.read_csv('D:\\Personal\\Msc\\CMM706 Text Analytics\\Coursework\\\datasets\\test_file_names.csv')

# %%
test_file_names
# Out:
#                                     0
# 0     vaR1bLVLx4.8982171058957447.txt
# 1     Lf1HdmFkTL.3782724598334164.txt
# 2     SR39fGMc1M.9184856358627767.txt
# 3    4rvLk0xo1M.08269361309440426.txt
# 4     epSIjmMhNj.6197248307930763.txt
# ..                                ...
# 296   0bAzOpHE0b.9626727894425651.txt
# 297   xtJYbbvzWa.4302494395097122.txt
# 298  HEhdm3vnh3.01944003899232105.txt
# 299   eyjBCtWAWj.2156795479497241.txt
# 300   3N2fip6s9z.7103179068412689.txt
#
# [301 rows x 1 columns]

# %%
# Generating urls for file names.

# %%
list_of_test_url = []
for index, row in test_file_names.iterrows():
#     print(row[0].split('.'))
    url = 'https://t.co/' + row[0].split('.')[0]
    list_of_test_url.append([row[0] , row[0].split('.')[0], url ])

# %%
list_of_test_url_df = pd.DataFrame(list_of_test_url)
list_of_test_url_df
# Out:
#                                     0           1                        2
# 0     vaR1bLVLx4.8982171058957447.txt  vaR1bLVLx4  https://t.co/vaR1bLVLx4
# 1     Lf1HdmFkTL.3782724598334164.txt  Lf1HdmFkTL  https://t.co/Lf1HdmFkTL
# 2     SR39fGMc1M.9184856358627767.txt  SR39fGMc1M  https://t.co/SR39fGMc1M
# 3    4rvLk0xo1M.08269361309440426.txt  4rvLk0xo1M  https://t.co/4rvLk0xo1M
# 4     epSIjmMhNj.6197248307930763.txt  epSIjmMhNj  https://t.co/epSIjmMhNj
# ..                                ...         ...                      ...
# 296   0bAzOpHE0b.9626727894425651.txt  0bAzOpHE0b  https://t.co/0bAzOpHE0b
# 297   xtJYbbvzWa.4302494395097122.txt  xtJYbbvzWa  https://t.co/xtJYbbvzWa
# 298  HEhdm3vnh3.01944003899232105.txt  HEhdm3vnh3  https://t.co/HEhdm3vnh3
# 299   eyjBCtWAWj.2156795479497241.txt  eyjBCtWAWj  https://t.co/eyjBCtWAWj
# 300   3N2fip6s9z.7103179068412689.txt  3N2fip6s9z  https://t.co/3N2fip6s9z
#
# [301 rows x 3 columns]

# %%
list_of_test_url_df.to_csv('D:\\Personal\\Msc\\CMM706 Text Analytics\\Coursework\\\datasets\\test_data_urls.csv', index=None)

# %%
t = [
'Basketball',
'Tennis',
'NoSport',
'Fighting',
'Basketball',
'Soccer',
'Soccer',
'Hockey',
'Football',
'MotorSport',
'Baseball',
'Basketball',
'Football',
'Soccer',
'MotorSport',
'Golf',
'Basketball',
'OtherSports',
'Tennis',
'Football',
'Football',
'Baseball',
'Soccer',
'Soccer',
'Soccer',
'Baseball',
'Hockey',
'NoSport',
'Golf',
'Football',
'Basketball',
'Tennis',
'Golf',
'Football',
'Hockey',
'Football',
'Baseball',
'Football',
'Football',
'Soccer',
'Hockey',
'Soccer',
'Basketball',
'Basketball',
'Football',
'Soccer',
'Fighting',
'Tennis',
'Football',
'Basketball',
'Tennis',
'Golf',
'Football',
'Baseball',
'Fighting',
'Basketball',
'OtherSports',
'Soccer',
'NoSport',
'OtherSports',
'Football',
'Football',
'Basketball',
'Basketball',
'OtherSports',
'Soccer',
'Basketball',
'Football',
'Football',
'Tennis',
'Basketball',
'Hockey',
'Football',
'Tennis',
'Hockey',
'Soccer',
'Soccer',
'Soccer',
'Fighting',
'Basketball',
'NoSport',
'Hockey',
'Fighting',
'Football',
'Basketball',
'Football',
'OtherSports',
'Football',
'Football',
'Soccer',
'Soccer',
'Basketball',
'Soccer',
'Soccer',
'Fighting',
'MotorSport',
'Golf',
'Basketball',
'Basketball',
'Football',
'Hockey',
'Golf',
'Football',
'Golf',
'Basketball',
'MotorSport',
'OtherSports',
'Fighting',
'MotorSport',
'Football',
'Basketball',
'Football',
'Golf',
'Basketball',
'Soccer',
'Soccer',
'Football',
'Basketball',
'Basketball',
'Baseball',
'Soccer',
'Football',
'Football',
'Football',
'Soccer',
'NoSport',
'Basketball',
'Basketball',
'Football',
'Football',
'Basketball',
'Fighting',
'Football',
'Basketball',
'Football',
'Football',
'Basketball',
'MotorSport',
'Football',
'NoSport',
'Football',
'Football',
'Hockey',
'Baseball',
'Soccer',
'Basketball',
'NoSport',
'Football',
'Soccer',
'Soccer',
'Football',
'Soccer',
'NoSport',
'Fighting',
'Football',
'Basketball',
'Soccer',
'Basketball',
'Soccer',
'NoSport',
'Hockey',
'Football',
'Football',
'MotorSport',
'OtherSports',
'Basketball',
'Basketball',
'Basketball',
'Hockey',
'Basketball',
'Basketball',
'MotorSport',
'Tennis',
'Basketball',
'NoSport',
'Soccer',
'OtherSports',
'MotorSport',
'NoSport',
'Hockey',
'Soccer',
'Football',
'Football',
'Soccer',
'Football',
'Soccer',
'Fighting',
'Golf',
'Basketball',
'Basketball',
'Baseball',
'Fighting',
'Soccer',
'NoSport',
'Basketball',
'MotorSport',
'Basketball',
'Football',
'Basketball',
'Football',
'NoSport',
'Hockey',
'NoSport',
'Basketball',
'Tennis',
'NoSport',
'Baseball',
'Soccer',
'Football',
'Soccer',
'NoSport',
'Soccer',
'Tennis',
'Hockey',
'Football',
'Football',
'Golf',
'Baseball',
'Soccer',
'Football',
'Hockey',
'OtherSports',
'Basketball',
'Fighting',
'Basketball',
'Fighting',
'Soccer',
'Basketball',
'Golf',
'MotorSport',
'Basketball',
'Basketball',
'Hockey',
'Baseball',
'Football',
'OtherSports',
'Basketball',
'Tennis',
'Hockey',
'Hockey',
'Football',
'Golf',
'NoSport',
'Basketball',
'Baseball',
'Soccer',
'OtherSports',
'Baseball',
'Basketball',
'Hockey',
'Football',
'Fighting',
'Basketball',
'NoSport',
'Football',
'Soccer',
'Football',
'Tennis',
'Football',
'Football',
'Football',
'Football',
'Soccer',
'Football',
'Football',
'Football',
'Hockey',
'Fighting',
'Basketball',
'Soccer',
'Basketball',
'Baseball',
'Tennis',
'Soccer',
'Hockey',
'Soccer',
'Football',
'Hockey',
'Soccer',
'Hockey',
'Soccer',
'MotorSport',
'Soccer',
'Golf',
'Football',
'Football',
'Hockey',
'Soccer',
'Hockey',
'Hockey',
'Basketball',
'Hockey',
'Football',
'Baseball',
'Basketball',
'Baseball',
'Fighting',
'Basketball',
]

# %%
set(t)
# Out:
# {'Baseball',
#  'Basketball',
#  'Fighting',
#  'Football',
#  'Golf',
#  'Hockey',
#  'MotorSport',
#  'NoSport',
#  'OtherSports',
#  'Soccer',
#  'Tennis'}

# %%
for i in t:
